# %% [markdown]
# # Results

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.insert(0, '..')
from utils import plot_stroke, plot_stroke_list

# %% [markdown]
# This is what you should modify:

# %%
from models.dummy import generate_unconditionally, generate_conditionally, recognize_stroke

# %% [markdown]
# Please, don't modify anything below.
#
# ### Unconditional generation:

# %%
stroke = generate_unconditionally()
plot_stroke(stroke)

# %% [markdown]
# ### Conditional generation:

# %%
stroke_list = generate_conditionally(text='welcome to my repository', random_seed=7)
plot_stroke_list(stroke_list)

# %% [markdown]
# ### Handwriting recognition:

# %%
text = recognize_stroke(stroke)
print(text)
# Out:
# welcome to lyrebird
